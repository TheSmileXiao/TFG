# %% [markdown]
# # Clasificaciones de imagenes con YOLO

# %% [markdown]
# ##Importar los paquetes

# %%
# !pip install ultralytics fiftyone
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ultralytics
#   Downloading ultralytics-8.0.117-py3-none-any.whl (599 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.6/599.6 kB 16.6 MB/s eta 0:00:00
# Collecting fiftyone
#   Downloading fiftyone-0.21.0-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 104.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (8.4.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.27.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.15.2+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Collecting aiofiles (from fiftyone)
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Collecting argcomplete (from fiftyone)
#   Downloading argcomplete-3.1.1-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.5/41.5 kB 6.2 MB/s eta 0:00:00
# Collecting boto3 (from fiftyone)
#   Downloading boto3-1.26.152-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from fiftyone) (5.3.0)
# Collecting dacite<1.8.0,>=1.6.0 (from fiftyone)
#   Downloading dacite-1.7.0-py3-none-any.whl (12 kB)
# Collecting Deprecated (from fiftyone)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting eventlet (from fiftyone)
#   Downloading eventlet-0.33.3-py2.py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 27.0 MB/s eta 0:00:00
# Collecting ftfy (from fiftyone)
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from fiftyone) (0.18.3)
# Collecting hypercorn>=0.13.2 (from fiftyone)
#   Downloading Hypercorn-0.14.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2>=3 in /usr/local/lib/python3.10/dist-packages (from fiftyone) (3.1.2)
# Collecting kaleido (from fiftyone)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 23.3 MB/s eta 0:00:00
# Collecting mongoengine==0.24.2 (from fiftyone)
#   Downloading mongoengine-0.24.2-py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.9/108.9 kB 15.2 MB/s eta 0:00:00
# Collecting motor>=2.5 (from fiftyone)
#   Downloading motor-3.1.2-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fiftyone) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fiftyone) (23.1)
# Requirement already satisfied: plotly>=4.14 in /usr/local/lib/python3.10/dist-packages (from fiftyone) (5.13.1)
# Collecting pprintpp (from fiftyone)
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Collecting pymongo>=3.12 (from fiftyone)
#   Downloading pymongo-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 50.7 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from fiftyone) (2022.7.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from fiftyone) (2022.10.31)
# Collecting retrying (from fiftyone)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from fiftyone) (1.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from fiftyone) (0.19.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from fiftyone) (67.7.2)
# Collecting sseclient-py<2,>=1.7.2 (from fiftyone)
#   Downloading sseclient_py-1.7.2-py2.py3-none-any.whl (8.4 kB)
# Collecting sse-starlette<1,>=0.10.3 (from fiftyone)
#   Downloading sse_starlette-0.10.3-py3-none-any.whl (8.0 kB)
# Collecting starlette<0.27,>=0.24.0 (from fiftyone)
#   Downloading starlette-0.26.1-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 10.9 MB/s eta 0:00:00
# Collecting strawberry-graphql==0.138.1 (from fiftyone)
#   Downloading strawberry_graphql-0.138.1-py3-none-any.whl (192 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.5/192.5 kB 27.1 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fiftyone) (0.8.10)
# Collecting xmltodict (from fiftyone)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Collecting universal-analytics-python3<2,>=1.0.1 (from fiftyone)
#   Downloading universal_analytics_python3-1.1.1-py3-none-any.whl (10 kB)
# Collecting fiftyone-brain<0.13,>=0.12 (from fiftyone)
#   Downloading fiftyone_brain-0.12.0-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 11.6 MB/s eta 0:00:00
# Collecting fiftyone-db<0.5,>=0.4 (from fiftyone)
#   Downloading fiftyone_db-0.4.0-py3-none-manylinux1_x86_64.whl (37.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.8/37.8 MB 50.0 MB/s eta 0:00:00
# Collecting voxel51-eta<0.11,>=0.10 (from fiftyone)
#   Downloading voxel51_eta-0.10.0-py2.py3-none-any.whl (568 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.9/568.9 kB 53.4 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from fiftyone) (4.7.0.72)
# Collecting graphql-core<3.3.0,>=3.2.0 (from strawberry-graphql==0.138.1->fiftyone)
#   Downloading graphql_core-3.2.3-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from strawberry-graphql==0.138.1->fiftyone) (2.8.2)
# Requirement already satisfied: typing_extensions<5.0.0,>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from strawberry-graphql==0.138.1->fiftyone) (4.5.0)
# Collecting h11 (from hypercorn>=0.13.2->fiftyone)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.0 MB/s eta 0:00:00
# Collecting h2>=3.1.0 (from hypercorn>=0.13.2->fiftyone)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 8.7 MB/s eta 0:00:00
# Collecting priority (from hypercorn>=0.13.2->fiftyone)
#   Downloading priority-2.0.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from hypercorn>=0.13.2->fiftyone) (0.10.2)
# Collecting wsproto>=0.14.0 (from hypercorn>=0.13.2->fiftyone)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3->fiftyone) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->ultralytics) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.14->fiftyone) (8.2.2)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo>=3.12->fiftyone)
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 34.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.27,>=0.24.0->fiftyone) (3.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7.0->ultralytics) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7.0->ultralytics) (16.0.5)
# Collecting httpx>=0.10.0 (from universal-analytics-python3<2,>=1.0.1->fiftyone)
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 11.5 MB/s eta 0:00:00
# Collecting dill (from voxel51-eta<0.11,>=0.10->fiftyone)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: glob2 in /usr/local/lib/python3.10/dist-packages (from voxel51-eta<0.11,>=0.10->fiftyone) (0.7)
# Collecting jsonlines (from voxel51-eta<0.11,>=0.10->fiftyone)
#   Downloading jsonlines-3.1.0-py3-none-any.whl (8.6 kB)
# Collecting py7zr (from voxel51-eta<0.11,>=0.10->fiftyone)
#   Downloading py7zr-0.20.5-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 10.2 MB/s eta 0:00:00
# Collecting rarfile (from voxel51-eta<0.11,>=0.10->fiftyone)
#   Downloading rarfile-4.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from voxel51-eta<0.11,>=0.10->fiftyone) (1.16.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from voxel51-eta<0.11,>=0.10->fiftyone) (2.4.0)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from voxel51-eta<0.11,>=0.10->fiftyone) (4.3)
# Collecting botocore<1.30.0,>=1.29.152 (from boto3->fiftyone)
#   Downloading botocore-1.29.152-py3-none-any.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 119.3 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->fiftyone)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3->fiftyone)
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated->fiftyone) (1.14.1)
# Requirement already satisfied: greenlet>=0.3 in /usr/local/lib/python3.10/dist-packages (from eventlet->fiftyone) (2.0.2)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->fiftyone) (0.2.6)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->fiftyone) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->fiftyone) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->fiftyone) (1.4.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fiftyone) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fiftyone) (3.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.27,>=0.24.0->fiftyone) (1.3.0)
# Collecting hyperframe<7,>=6.0 (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone)
#   Downloading httpcore-0.17.2-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->voxel51-eta<0.11,>=0.10->fiftyone) (23.1.0)
# Collecting texttable (from py7zr->voxel51-eta<0.11,>=0.10->fiftyone)
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Collecting pycryptodomex>=3.6.6 (from py7zr->voxel51-eta<0.11,>=0.10->fiftyone)
#   Downloading pycryptodomex-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 101.1 MB/s eta 0:00:00
# Collecting pyzstd>=0.14.4 (from py7zr->voxel51-eta<0.11,>=0.10->fiftyone)
#   Downloading pyzstd-0.15.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 49.8 MB/s eta 0:00:00
# Collecting pyppmd<1.1.0,>=0.18.1 (from py7zr->voxel51-eta<0.11,>=0.10->fiftyone)
#   Downloading pyppmd-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 20.6 MB/s eta 0:00:00
# Collecting pybcj>=0.6.0 (from py7zr->voxel51-eta<0.11,>=0.10->fiftyone)
#   Downloading pybcj-1.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.8/49.8 kB 7.7 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3 (from py7zr->voxel51-eta<0.11,>=0.10->fiftyone)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting brotli>=1.0.9 (from py7zr->voxel51-eta<0.11,>=0.10->fiftyone)
#   Downloading Brotli-1.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 115.0 MB/s eta 0:00:00
# Collecting inflate64>=0.3.1 (from py7zr->voxel51-eta<0.11,>=0.10->fiftyone)
#   Downloading inflate64-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.0->ultralytics) (1.3.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.10/dist-packages (from tzlocal->voxel51-eta<0.11,>=0.10->fiftyone) (0.1.0.post0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from pytz-deprecation-shim->tzlocal->voxel51-eta<0.11,>=0.10->fiftyone) (2023.3)
# Installing collected packages: texttable, sseclient-py, rarfile, pprintpp, kaleido, brotli, xmltodict, retrying, pyzstd, pyppmd, pycryptodomex, pybcj, priority, multivolumefile, jsonlines, jmespath, inflate64, hyperframe, hpack, h11, graphql-core, ftfy, fiftyone-db, dnspython, dill, Deprecated, dacite, argcomplete, aiofiles, wsproto, strawberry-graphql, starlette, pymongo, py7zr, httpcore, h2, eventlet, botocore, voxel51-eta, sse-starlette, s3transfer, motor, mongoengine, hypercorn, httpx, fiftyone-brain, universal-analytics-python3, boto3, fiftyone, ultralytics
# Successfully installed Deprecated-1.2.14 aiofiles-23.1.0 argcomplete-3.1.1 boto3-1.26.152 botocore-1.29.152 brotli-1.0.9 dacite-1.7.0 dill-0.3.6 dnspython-2.3.0 eventlet-0.33.3 fiftyone-0.21.0 fiftyone-brain-0.12.0 fiftyone-db-0.4.0 ftfy-6.1.1 graphql-core-3.2.3 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-0.17.2 httpx-0.24.1 hypercorn-0.14.3 hyperframe-6.0.1 inflate64-0.3.1 jmespath-1.0.1 jsonlines-3.1.0 kaleido-0.2.1 mongoengine-0.24.2 motor-3.1.2 multivolumefile-0.2.3 pprintpp-0.4.0 priority-2.0.0 py7zr-0.20.5 pybcj-1.0.1 pycryptodomex-3.18.0 pymongo-4.3.3 pyppmd-1.0.0 pyzstd-0.15.8 rarfile-4.0 retrying-1.3.4 s3transfer-0.6.1 sse-starlette-0.10.3 sseclient-py-1.7.2 starlette-0.26.1 strawberry-graphql-0.138.1 texttable-1.6.7 ultralytics-8.0.117 universal-analytics-python3-1.1.1 voxel51-eta-0.10.0 wsproto-1.2.0 xmltodict-0.13.0

# %%
import zipfile
import os
import shutil
import random
import fiftyone               as fo
import fiftyone.utils.random        as four
import matplotlib.pyplot          as plt
from ultralytics          import YOLO
from google.colab         import drive
# Out:
# Migrating database to v0.21.0
# INFO:fiftyone.migrations.runner:Migrating database to v0.21.0

# %% [markdown]
# ##BUILD ROBOCUP_2019 Dataset

# %% [markdown]
# ###Dataset details
# RoboCup Dataset contains 196195 images.
#
# 8 main parent categories that contain 180 children categories.
#
# 80% for train
#
# 20% for valid

# %% [markdown]
# ###Build dataset

# %% [markdown]
# ###Connect to my oneDrive

# %%
drive.mount('/content/drive')
ruta_archivo_zip = '/content/drive/MyDrive/Colab Notebooks/data_subclass.zip'
ruta_destino = './'
with zipfile.ZipFile(ruta_archivo_zip, 'r') as archivo_zip:
    # Extraer el archivo deseado en la ruta de destino
    archivo_zip.extractall(ruta_destino)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###transforming data to suit the yolo model

# %%
def transform_dataset(root_dir, output_dir, train_ratio=0.8):
    # Create the output directory
    os.makedirs(output_dir, exist_ok=True)
    train_dir = os.path.join(output_dir, 'train')
    val_dir = os.path.join(output_dir, 'val')
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)

    # Get the list of classes in the root directory
    classes = [d for d in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, d))]

    for class_name in classes:
        class_dir = os.path.join(root_dir, class_name)
        if not os.path.isdir(class_dir):
            continue

        # Get the list of images in the current class
        images = [f for f in os.listdir(class_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

        # Shuffle the images randomly
        random.shuffle(images)

        # Calculate the number of training images based on the specified ratio
        train_size = int(len(images) * train_ratio)

        # Create the class directories in the training and validation sets
        train_class_dir = os.path.join(train_dir, class_name)
        val_class_dir = os.path.join(val_dir, class_name)
        os.makedirs(train_class_dir, exist_ok=True)
        os.makedirs(val_class_dir, exist_ok=True)

        # Copy the training images
        for img in images[:train_size]:
            src_path = os.path.join(class_dir, img)
            dst_path = os.path.join(train_class_dir, f"{os.path.splitext(img)[0]}_{class_name}.png")
            shutil.copy(src_path, dst_path)

        # Copy the validation images
        for img in images[train_size:]:
            src_path = os.path.join(class_dir, img)
            dst_path = os.path.join(val_class_dir, f"{os.path.splitext(img)[0]}_{class_name}.png")
            shutil.copy(src_path, dst_path)

# %%
root_dir   = '/content/training_data'   # Path to the original dataset
output_dir  = '/content/dataset'      # Path for the resized dataset

transform_dataset(root_dir, output_dir, train_ratio=0.8)

# %% [markdown]
# ##YOLO

# %% [markdown]
# ###Train

# %%
# Load a model
model = YOLO('yolov8x-cls.yaml').load('yolov8x-cls.pt')  # build from YAML and transfer weights

# Train the model
model.train(data='/content/dataset', epochs=50, imgsz=224, verbose=True)

# %% [markdown]
# ###Val

# %%
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.top1   # top1 accuracy
metrics.top5   # top5 accuracy

# %% [markdown]
# ##Superclass

# %% [markdown]
# ###Dataset details
# RoboCup Dataset contains 196195 images.
#
# 8 main parent categories that contain 180 children categories.
#
# 80% for train
#
# 20% for valid

# %% [markdown]
# ###Build dataset

# %% [markdown]
# ###Connect to my oneDrive

# %%
drive.mount('/content/drive')
ruta_archivo_zip = '/content/drive/MyDrive/Colab Notebooks/data_superclass.zip'
ruta_destino = './'
with zipfile.ZipFile(ruta_archivo_zip, 'r') as archivo_zip:
    # Extraer el archivo deseado en la ruta de destino
    archivo_zip.extractall(ruta_destino)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###transforming data to suit the yolo model

# %%
def transform_dataset(root_dir, output_dir, train_ratio=0.8):
    # Crear el directorio de salida
    os.makedirs(output_dir, exist_ok=True)
    train_dir = os.path.join(output_dir, 'train')
    val_dir = os.path.join(output_dir, 'val')
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)

    # Obtener la lista de clases en el directorio raíz
    classes = [d for d in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, d))]

    for class_name in classes:
        class_dir = os.path.join(root_dir, class_name)
        subclasses = [d for d in os.listdir(class_dir) if os.path.isdir(os.path.join(class_dir, d))]

        for subclass_name in subclasses:
            subclass_dir = os.path.join(class_dir, subclass_name)

            # Obtener la lista de imágenes en la subclase actual
            images = [f for f in os.listdir(subclass_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

            # Mezclar las imágenes al azar
            random.shuffle(images)

            # Calcular el tamaño del conjunto de entrenamiento basado en el ratio especificado
            train_size = int(len(images) * train_ratio)

            # Crear los directorios de clase en los conjuntos de entrenamiento y validación
            train_class_dir = os.path.join(train_dir, class_name)
            val_class_dir = os.path.join(val_dir, class_name)
            os.makedirs(train_class_dir, exist_ok=True)
            os.makedirs(val_class_dir, exist_ok=True)

            # Copiar las imágenes de entrenamiento
            for img in images[:train_size]:
                src_path = os.path.join(subclass_dir, img)
                dst_path = os.path.join(train_class_dir, f"{os.path.splitext(img)[0]}_{class_name}.png")
                shutil.copy(src_path, dst_path)

            # Copiar las imágenes de validación
            for img in images[train_size:]:
                src_path = os.path.join(subclass_dir, img)
                dst_path = os.path.join(val_class_dir, f"{os.path.splitext(img)[0]}_{class_name}.png")
                shutil.copy(src_path, dst_path)

# %%
root_dir   = '/content/dataset_superclass'   # Path to the original dataset
output_dir  = '/content/dataset'      # Path for the resized dataset

transform_dataset(root_dir, output_dir, train_ratio=0.8)

# %% [markdown]
# ##YOLO

# %% [markdown]
# ###Train

# %%
# Load a model
model = YOLO('yolov8x-cls.yaml').load('yolov8x-cls.pt')  # build from YAML and transfer weights

# Train the model
model.train(data='/content/dataset', epochs=50, imgsz=224, verbose=True)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   7375360  ultralytics.nn.modules.conv.Conv             [640, 1280, 3, 2]
#   8                  -1  3  27865600  ultralytics.nn.modules.block.C2f             [1280, 1280, 3, True]
#   9                  -1  1   2921960  ultralytics.nn.modules.head.Classify         [1280, 1000]
# YOLOv8x-cls summary: 183 layers, 57422840 parameters, 57422840 gradients
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x-cls.pt to yolov8x-cls.pt...
# 100%|██████████| 110M/110M [00:01<00:00, 85.9MB/s]
# Transferred 302/302 items from pretrained weights
# Ultralytics YOLOv8.0.117 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# yolo/engine/trainer: task=classify, mode=train, model=yolov