# %% [markdown]
# # Clasificaciones de imagenes con YOLO epoch 70

# %% [markdown]
# ##Importar los paquetes

# %%
# !pip install ultralytics fiftyone

# %%
import zipfile
import os
import shutil
import random
import matplotlib.pyplot          as plt
from ultralytics          import YOLO
from google.colab         import drive

# %% [markdown]
# ##BUILD ROBOCUP_2019 Dataset

# %% [markdown]
# ###Dataset details
# RoboCup Dataset contains 196195 images.
#
# 8 main parent categories that contain 180 children categories.
#
# 80% for train
#
# 20% for valid

# %% [markdown]
# ###Build dataset

# %% [markdown]
# ###Connect to my oneDrive

# %%
#drive.mount('/content/drive')
ruta_archivo_zip = '/content/drive/MyDrive/Colab Notebooks/data_subclass.zip'
ruta_destino = './'
with zipfile.ZipFile(ruta_archivo_zip, 'r') as archivo_zip:
    # Extraer el archivo deseado en la ruta de destino
    archivo_zip.extractall(ruta_destino)

# %% [markdown]
# ###transforming data to suit the yolo model

# %%
def transform_dataset(root_dir, output_dir, train_ratio=0.8):
    # Create the output directory
    os.makedirs(output_dir, exist_ok=True)
    train_dir = os.path.join(output_dir, 'train')
    val_dir = os.path.join(output_dir, 'val')
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)

    # Get the list of classes in the root directory
    classes = [d for d in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, d))]

    for class_name in classes:
        class_dir = os.path.join(root_dir, class_name)
        if not os.path.isdir(class_dir):
            continue

        # Get the list of images in the current class
        images = [f for f in os.listdir(class_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

        # Shuffle the images randomly
        random.shuffle(images)

        # Calculate the number of training images based on the specified ratio
        train_size = int(len(images) * train_ratio)

        # Create the class directories in the training and validation sets
        train_class_dir = os.path.join(train_dir, class_name)
        val_class_dir = os.path.join(val_dir, class_name)
        os.makedirs(train_class_dir, exist_ok=True)
        os.makedirs(val_class_dir, exist_ok=True)

        # Copy the training images
        for img in images[:train_size]:
            src_path = os.path.join(class_dir, img)
            dst_path = os.path.join(train_class_dir, f"{os.path.splitext(img)[0]}_{class_name}.png")
            shutil.copy(src_path, dst_path)

        # Copy the validation images
        for img in images[train_size:]:
            src_path = os.path.join(class_dir, img)
            dst_path = os.path.join(val_class_dir, f"{os.path.splitext(img)[0]}_{class_name}.png")
            shutil.copy(src_path, dst_path)

# %%
root_dir   = '/content/training_data'   # Path to the original dataset
output_dir  = '/content/dataset'      # Path for the resized dataset

transform_dataset(root_dir, output_dir, train_ratio=0.8)

# %% [markdown]
# ##YOLO

# %% [markdown]
# ###Train

# %%
# Load a model
model = YOLO('yolov8x-cls.yaml').load('yolov8x-cls.pt')  # build from YAML and transfer weights

# Train the model
model.train(data='/content/dataset', epochs=70, patience=70, imgsz=224,
      verbose=True, batch=64,
      project='/content/drive/MyDrive/Colab Notebooks/save_models', name='yolo_70epoch/classify')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   7375360  ultralytics.nn.modules.conv.Conv             [640, 1280, 3, 2]
#   8                  -1  3  27865600  ultralytics.nn.modules.block.C2f             [1280, 1280, 3, True]
#   9                  -1  1   2921960  ultralytics.nn.modules.head.Classify         [1280, 1000]
# YOLOv8x-cls summary: 183 layers, 57422840 parameters, 57422840 gradients
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x-cls.pt to yolov8x-cls.pt...
# 100%|██████████| 110M/110M [00:05<00:00, 21.3MB/s]
# Transferred 302/302 items from pretrained weights
# Ultralytics YOLOv8.0.119 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# yolo/engine/trainer: task=classify, mode=train, model=yolov8x-cls.yaml, data=/content/dataset, epochs=70, patience=70, batch=64, imgsz=224, save=True, save_period=-1, cache=False, device=None, workers=8, project=/content/drive/MyDrive/Colab Notebooks/save_models, name=yolo_100epoch/classify, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=/content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch/classify
# Overriding model.yaml nc=1000 with nc=180
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   7375360  ultralytics.nn.modules.conv.Conv             [640, 1280, 3, 2]
#   8                  -1  3  27865600  ultralytics.nn.modules.block.C2f             [1280, 1280, 3, True]
#   9                  -1  1   1871540  ultralytics.nn.modules.head.Classify         [1280, 180]
# YOLOv8x-cls summary: 183 layers, 56372420 parameters, 56372420 gradients
# Transferred 300/302 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir /content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch/classify', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 7.73MB/s]
# AMP: checks passed ✅
# albumentations: RandomResizedCrop(p=1.0, height=224, width=224, scale=(0.5, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1), HorizontalFlip(p=0.5), ColorJitter(p=0.5, brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.30000000000000004, 1.7], hue=[-0.015, 0.015]), Normalize(p=1.0, mean=(0.0, 0.0, 0.0), std=(1.0, 1.0, 1.0), max_pixel_value=255.0), ToTensorV2(always_apply=True, p=1.0, transpose_mask=False)
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 50 weight(decay=0.0), 51 weight(decay=0.0005), 51 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to /content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch/classify
# Starting training for 70 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/70       4.9G      5.336         64        224:   0%|          | 4/2452 [00:02<17:35,  2.32it/s]Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
#        1/70       4.9G      5.333         64        224:   0%|          | 10/2452 [00:03<05:46,  7.04it/s]
# 100%|██████████| 755k/755k [00:00<00:00, 45.4MB/s]
#
#   0%|          | 0.00/755k [00:00<?, ?B/s]
# 100%|██████████| 755k/755k [00:00<00:00, 6.39MB/s]
#        1/70       4.9G      3.603         19        224: 100%|██████████| 2452/2452 [03:25<00:00, 11.91it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.64it/s]
#                    all      0.421      0.728
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/70      5.62G      2.199         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.91it/s]
#                    all      0.481      0.781
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/70      5.59G      2.109         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.45it/s]
#                    all      0.476      0.774
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/70      5.56G      2.184         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.08it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.95it/s]
#                    all      0.511        0.8
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/70      5.62G      2.052         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.07it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.57it/s]
#                    all      0.535      0.812
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/70      5.62G       1.97         19        224: 100%|██████████| 2452/2452 [03:22<00:00, 12.08it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.20it/s]
#                    all      0.549      0.823
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/70       5.6G      1.907         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.07it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.74it/s]
#                    all      0.556      0.825
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/70      5.62G      1.848         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.08it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.93it/s]
#                    all       0.56      0.828
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/70       5.6G      1.801         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.07it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.46it/s]
#                    all      0.562       0.83
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/70      5.62G      1.758         19        224: 100%|██████████| 2452/2452 [03:22<00:00, 12.09it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.05it/s]
#                    all      0.563      0.831
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/70      5.62G      1.714         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.94it/s]
#                    all      0.565      0.832
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/70      5.62G      1.671         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.65it/s]
#                    all      0.566      0.832
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/70      5.62G      1.637         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.28it/s]
#                    all      0.568      0.833
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/70      5.63G      1.599         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.86it/s]
#                    all      0.569      0.835
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/70       5.6G      1.563         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.79it/s]
#                    all      0.571      0.835
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/70       5.6G      1.523         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.23it/s]
#                    all      0.572      0.836
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/70       5.6G      1.486         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.91it/s]
#                    all      0.574      0.837
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/70      5.62G      1.454         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:15<00:00, 20.43it/s]
#                    all      0.575      0.837
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/70       5.6G      1.417         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.07it/s]
#                    all      0.576      0.838
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/70      5.62G      1.382         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:15<00:00, 20.48it/s]
#                    all      0.577      0.837
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/70      5.62G      1.354         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.86it/s]
#                    all      0.579      0.838
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/70      5.62G      1.324         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.07it/s]
#                    all       0.58      0.838
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/70      5.62G      1.284         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.66it/s]
#                    all      0.582      0.839
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/70      5.63G       1.25         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.20it/s]
#                    all      0.584      0.839
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/70      5.57G       1.22         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:15<00:00, 20.45it/s]
#                    all      0.585      0.838
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/70       5.6G      1.189         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:15<00:00, 20.43it/s]
#                    all      0.585      0.838
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/70       5.6G      1.152         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.11it/s]
#                    all      0.586      0.838
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/70      5.62G      1.124         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.68it/s]
#                    all      0.586      0.838
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/70       5.6G      1.094         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.85it/s]
#                    all      0.586      0.839
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/70      5.62G      1.065         19        224: 100%|██████████| 2452/2452 [03:24<00:00, 12.01it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.62it/s]
#                    all      0.586      0.838
#
#       Epoch    GPU_mem       loss  Instances       Size
#       31/70      5.63G      1.027         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.07it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.90it/s]
#                    all      0.589      0.838
#
#       Epoch    GPU_mem       loss  Instances       Size
#       32/70      5.62G      1.004         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.82it/s]
#                    all      0.588      0.838
#
#       Epoch    GPU_mem       loss  Instances       Size
#       33/70      5.62G     0.9615         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.77it/s]
#                    all      0.588      0.837
#
#       Epoch    GPU_mem       loss  Instances       Size
#       34/70      5.63G     0.9348         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.86it/s]
#                    all      0.589      0.836
#
#       Epoch    GPU_mem       loss  Instances       Size
#       35/70      5.66G     0.8969         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:15<00:00, 20.53it/s]
#                    all      0.589      0.837
#
#       Epoch    GPU_mem       loss  Instances       Size
#       36/70       5.6G     0.8725         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.06it/s]
#                    all      0.589      0.836
#
#       Epoch    GPU_mem       loss  Instances       Size
#       37/70       5.6G     0.8405         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.91it/s]
#                    all      0.589      0.836
#
#       Epoch    GPU_mem       loss  Instances       Size
#       38/70       5.6G     0.8139         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.63it/s]
#                    all      0.589      0.836
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/70      5.64G     0.7764         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.95it/s]
#                    all      0.588      0.835
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/70      5.62G     0.7428         19        224: 100%|██████████| 2452/2452 [03:24<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.23it/s]
#                    all      0.589      0.836
#
#       Epoch    GPU_mem       loss  Instances       Size
#       41/70      5.62G     0.7118         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:15<00:00, 20.47it/s]
#                    all      0.588      0.835
#
#       Epoch    GPU_mem       loss  Instances       Size
#       42/70      5.63G      0.683         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.22it/s]
#                    all       0.59      0.834
#
#       Epoch    GPU_mem       loss  Instances       Size
#       43/70      5.62G     0.6539         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.93it/s]
#                    all      0.589      0.834
#
#       Epoch    GPU_mem       loss  Instances       Size
#       44/70      5.66G     0.6291         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.71it/s]
#                    all      0.588      0.833
#
#       Epoch    GPU_mem       loss  Instances       Size
#       45/70      5.62G     0.5976         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:15<00:00, 20.52it/s]
#                    all      0.587      0.833
#
#       Epoch    GPU_mem       loss  Instances       Size
#       46/70       5.6G     0.5664         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.33it/s]
#                    all      0.588      0.833
#
#       Epoch    GPU_mem       loss  Instances       Size
#       47/70      5.62G     0.5424         19        224: 100%|██████████| 2452/2452 [03:24<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.87it/s]
#                    all      0.587      0.832
#
#       Epoch    GPU_mem       loss  Instances       Size
#       48/70      5.62G     0.5133         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.92it/s]
#                    all      0.587      0.832
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/70      5.63G     0.4805         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.99it/s]
#                    all      0.587      0.833
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/70      5.62G     0.4555         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.09it/s]
#                    all      0.586      0.831
#
#       Epoch    GPU_mem       loss  Instances       Size
#       51/70      5.62G     0.4335         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.08it/s]
#                    all      0.586      0.831
#
#       Epoch    GPU_mem       loss  Instances       Size
#       52/70       5.6G     0.4044         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.54it/s]
#                    all      0.586       0.83
#
#       Epoch    GPU_mem       loss  Instances       Size
#       53/70      5.58G     0.3776         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.13it/s]
#                    all      0.585      0.829
#
#       Epoch    GPU_mem       loss  Instances       Size
#       54/70      5.63G     0.3512         19        224: 100%|██████████| 2452/2452 [03:24<00:00, 12.01it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.04it/s]
#                    all      0.586      0.828
#
#       Epoch    GPU_mem       loss  Instances       Size
#       55/70      5.62G     0.3219         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:15<00:00, 20.44it/s]
#                    all      0.585      0.827
#
#       Epoch    GPU_mem       loss  Instances       Size
#       56/70      5.63G     0.2998         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.83it/s]
#                    all      0.584      0.828
#
#       Epoch    GPU_mem       loss  Instances       Size
#       57/70      5.63G     0.2723         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.63it/s]
#                    all      0.584      0.827
#
#       Epoch    GPU_mem       loss  Instances       Size
#       58/70      5.62G     0.2509         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.07it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.68it/s]
#                    all      0.583      0.827
#
#       Epoch    GPU_mem       loss  Instances       Size
#       59/70      5.63G     0.2308         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.79it/s]
#                    all      0.582      0.826
#
#       Epoch    GPU_mem       loss  Instances       Size
#       60/70      5.62G     0.2075         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.00it/s]
#                    all      0.583      0.825
#
#       Epoch    GPU_mem       loss  Instances       Size
#       61/70      5.62G     0.1858         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.56it/s]
#                    all      0.583      0.825
#
#       Epoch    GPU_mem       loss  Instances       Size
#       62/70      5.62G     0.1641         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.07it/s]
#                    all      0.582      0.824
#
#       Epoch    GPU_mem       loss  Instances       Size
#       63/70      5.59G     0.1463         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.75it/s]
#                    all      0.582      0.823
#
#       Epoch    GPU_mem       loss  Instances       Size
#       64/70      5.62G     0.1303         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.71it/s]
#                    all      0.582      0.822
#
#       Epoch    GPU_mem       loss  Instances       Size
#       65/70      5.63G     0.1159         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.62it/s]
#                    all      0.582      0.821
#
#       Epoch    GPU_mem       loss  Instances       Size
#       66/70      5.63G     0.1027         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.06it/s]
#                    all      0.582       0.82
#
#       Epoch    GPU_mem       loss  Instances       Size
#       67/70      5.62G     0.0902         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 20.63it/s]
#                    all      0.581      0.819
#
#       Epoch    GPU_mem       loss  Instances       Size
#       68/70      5.63G    0.07934         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.15it/s]
#                    all       0.58      0.819
#
#       Epoch    GPU_mem       loss  Instances       Size
#       69/70      5.62G    0.06968         19        224: 100%|██████████| 2452/2452 [03:24<00:00, 12.00it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:14<00:00, 21.12it/s]
#                    all       0.58      0.818
#
#       Epoch    GPU_mem       loss  Instances       Size
#       70/70      5.62G    0.06351         19        224: 100%|██████████| 2452/2452 [03:23<00:00, 12.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 308/308 [00:15<00:00, 20.04it/s]
#                    all      0.579      0.817
#
# 70 epochs completed in 4.285 hours.
# Optimizer stripped from /content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch/classify/weights/last.pt, 112.9MB
# Optimizer stripped from /content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch/classify/weights/best.pt, 112.9MB
# Results saved to /content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch/classify

# %% [markdown]
# ###Val

# %%
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.top1   # top1 accuracy
metrics.top5   # top5 accuracy
# Out:
# Ultralytics YOLOv8.0.119 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLOv8x-cls summary (fused): 133 layers, 56353780 parameters, 0 gradients
#                classes   top1_acc   top5_acc: 100%|██████████| 615/615 [00:23<00:00, 26.62it/s]
#                    all      0.586      0.839
# Speed: 0.1ms preprocess, 0.5ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch/classify2
# 0.8391839861869812

# %% [markdown]
# ##YOLO Superclass

# %% [markdown]
# ###Build dataset

# %% [markdown]
# ###Connect to my oneDrive

# %%
#drive.mount('/content/drive')
ruta_archivo_zip = '/content/drive/MyDrive/Colab Notebooks/data_superclass.zip'
ruta_destino = './'
with zipfile.ZipFile(ruta_archivo_zip, 'r') as archivo_zip:
    # Extraer el archivo deseado en la ruta de destino
    archivo_zip.extractall(ruta_destino)

# %% [markdown]
# ###transforming data to suit the yolo model

# %%
def transform_dataset(root_dir, output_dir, train_ratio=0.8):
    # Crear el directorio de salida
    os.makedirs(output_dir, exist_ok=True)
    train_dir = os.path.join(output_dir, 'train')
    val_dir = os.path.join(output_dir, 'val')
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)

    # Obtener la lista de clases en el directorio raíz
    classes = [d for d in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, d))]

    for class_name in classes:
        class_dir = os.path.join(root_dir, class_name)
        subclasses = [d for d in os.listdir(class_dir) if os.path.isdir(os.path.join(class_dir, d))]

        for subclass_name in subclasses:
            subclass_dir = os.path.join(class_dir, subclass_name)

            # Obtener la lista de imágenes en la subclase actual
            images = [f for f in os.listdir(subclass_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

            # Mezclar las imágenes al azar
            random.shuffle(images)

            # Calcular el tamaño del conjunto de entrenamiento basado en el ratio especificado
            train_size = int(len(images) * train_ratio)

            # Crear los directorios de clase en los conjuntos de entrenamiento y validación
            train_class_dir = os.path.join(train_dir, class_name)
            val_class_dir = os.path.join(val_dir, class_name)
            os.makedirs(train_class_dir, exist_ok=True)
            os.makedirs(val_class_dir, exist_ok=True)

            # Copiar las imágenes de entrenamiento
            for img in images[:train_size]:
                src_path = os.path.join(subclass_dir, img)
                dst_path = os.path.join(train_class_dir, f"{os.path.splitext(img)[0]}_{class_name}.png")
                shutil.copy(src_path, dst_path)

            # Copiar las imágenes de validación
            for img in images[train_size:]:
                src_path = os.path.join(subclass_dir, img)
                dst_path = os.path.join(val_class_dir, f"{os.path.splitext(img)[0]}_{class_name}.png")
                shutil.copy(src_path, dst_path)

# %%
root_dir   = '/content/dataset_superclass'   # Path to the original dataset
output_dir  = '/content/dataset_super'      # Path for the resized dataset

transform_dataset(root_dir, output_dir, train_ratio=0.8)

# %% [markdown]
# ###Train

# %%
# Load a model
model = YOLO('yolov8x-cls.yaml').load('yolov8x-cls.pt')  # build from YAML and transfer weights

# Train the model
model.train(data='/content/dataset_super', epochs=70, patience=70, imgsz=224,
      verbose=True, batch=64,
      project='/content/drive/MyDrive/Colab Notebooks/save_models', name='yolo_70epoch_superClass/classify')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   7375360  ultralytics.nn.modules.conv.Conv             [640, 1280, 3, 2]
#   8                  -1  3  27865600  ultralytics.nn.modules.block.C2f             [1280, 1280, 3, True]
#   9                  -1  1   2921960  ultralytics.nn.modules.head.Classify         [1280, 1000]
# YOLOv8x-cls summary: 183 layers, 57422840 parameters, 57422840 gradients
# Transferred 302/302 items from pretrained weights
# Ultralytics YOLOv8.0.119 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# yolo/engine/trainer: task=classify, mode=train, model=yolov8x-cls.yaml, data=/content/dataset_super, epochs=70, patience=70, batch=64, imgsz=224, save=True, save_period=-1, cache=False, device=None, workers=8, project=/content/drive/MyDrive/Colab Notebooks/save_models, name=yolo_100epoch_superClass/classify, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=/content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch_superClass/classify
# Overriding model.yaml nc=1000 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   7375360  ultralytics.nn.modules.conv.Conv             [640, 1280, 3, 2]
#   8                  -1  3  27865600  ultralytics.nn.modules.block.C2f             [1280, 1280, 3, True]
#   9                  -1  1   1651208  ultralytics.nn.modules.head.Classify         [1280, 8]
# YOLOv8x-cls summary: 183 layers, 56152088 parameters, 56152088 gradients
# Transferred 300/302 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir /content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch_superClass/classify', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# albumentations: RandomResizedCrop(p=1.0, height=224, width=224, scale=(0.5, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1), HorizontalFlip(p=0.5), ColorJitter(p=0.5, brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.30000000000000004, 1.7], hue=[-0.015, 0.015]), Normalize(p=1.0, mean=(0.0, 0.0, 0.0), std=(1.0, 1.0, 1.0), max_pixel_value=255.0), ToTensorV2(always_apply=True, p=1.0, transpose_mask=False)
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 50 weight(decay=0.0), 51 weight(decay=0.0005), 51 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to /content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch_superClass/classify
# Starting training for 70 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/70      4.83G     0.9844          6        224: 100%|██████████| 2429/2429 [03:24<00:00, 11.90it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:13<00:00, 21.92it/s]
#                    all      0.783      0.981
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/70      5.59G      0.658          6        224: 100%|██████████| 2429/2429 [03:23<00:00, 11.92it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.60it/s]
#                    all      0.808      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/70      5.52G     0.6396          6        224: 100%|██████████| 2429/2429 [03:23<00:00, 11.96it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.62it/s]
#                    all      0.796      0.983
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/70      5.58G     0.6931          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 11.98it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.48it/s]
#                    all      0.811      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/70      5.57G     0.6749          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 11.98it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.15it/s]
#                    all      0.822      0.985
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/70      5.52G     0.6657          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.01it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.33it/s]
#                    all      0.826      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/70      5.59G     0.6608          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.01it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.76it/s]
#                    all      0.829      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/70      5.52G      0.655          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.00it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.65it/s]
#                    all      0.828      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/70      5.53G     0.6481          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.01it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.16it/s]
#                    all      0.828      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/70      5.57G     0.6411          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.08it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.50it/s]
#                    all      0.828      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/70      5.52G     0.6365          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:13<00:00, 21.96it/s]
#                    all      0.829      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/70      5.56G     0.6277          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.24it/s]
#                    all      0.828      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/70      5.59G     0.6198          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.82it/s]
#                    all      0.828      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/70      5.59G      0.609          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 11.98it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.27it/s]
#                    all      0.828      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/70      5.59G     0.6017          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.99it/s]
#                    all      0.828      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/70      5.56G      0.594          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.01it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.50it/s]
#                    all      0.828      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/70      5.59G     0.5887          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.56it/s]
#                    all      0.828      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/70      5.57G     0.5753          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.00it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.41it/s]
#                    all      0.829      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/70      5.52G     0.5674          6        224: 100%|██████████| 2429/2429 [03:23<00:00, 11.96it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.30it/s]
#                    all       0.83      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/70      5.56G      0.558          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.00it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.73it/s]
#                    all       0.83      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/70      5.58G     0.5459          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 11.98it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.12it/s]
#                    all       0.83      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/70      5.52G      0.538          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 11.97it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.86it/s]
#                    all      0.831      0.987
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/70      5.52G      0.531          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 11.98it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.11it/s]
#                    all      0.831      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/70      5.56G     0.5196          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.53it/s]
#                    all      0.833      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/70      5.53G     0.5104          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.19it/s]
#                    all      0.835      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/70      5.58G     0.4979          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.00it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.24it/s]
#                    all      0.835      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/70      5.52G     0.4921          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.10it/s]
#                    all      0.835      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/70      5.56G     0.4783          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.60it/s]
#                    all      0.836      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/70      5.57G     0.4721          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.49it/s]
#                    all      0.837      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/70      5.52G     0.4621          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.16it/s]
#                    all      0.837      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       31/70      5.52G     0.4476          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.01it/s]
#                    all      0.837      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       32/70      5.56G      0.438          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.03it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.17it/s]
#                    all      0.838      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       33/70      5.52G     0.4302          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.00it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.10it/s]
#                    all      0.838      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       34/70      5.58G     0.4192          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.08it/s]
#                    all      0.837      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       35/70      5.58G       0.41          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.61it/s]
#                    all      0.838      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       36/70      5.56G     0.3975          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.25it/s]
#                    all      0.839      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       37/70      5.57G     0.3834          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.13it/s]
#                    all      0.839      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       38/70      5.52G     0.3758          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 11.98it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.17it/s]
#                    all      0.839      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/70      5.52G     0.3669          6        224: 100%|██████████| 2429/2429 [03:23<00:00, 11.96it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.63it/s]
#                    all      0.839      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/70      5.56G     0.3532          6        224: 100%|██████████| 2429/2429 [03:23<00:00, 11.96it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.35it/s]
#                    all      0.838      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       41/70      5.53G     0.3432          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.00it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.94it/s]
#                    all      0.839      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       42/70      5.58G     0.3276          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.54it/s]
#                    all       0.84      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       43/70      5.52G     0.3179          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.00it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.03it/s]
#                    all       0.84      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       44/70      5.56G     0.3069          6        224: 100%|██████████| 2429/2429 [03:23<00:00, 11.96it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 21.32it/s]
#                    all       0.84      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       45/70      5.57G     0.2937          6        224: 100%|██████████| 2429/2429 [03:23<00:00, 11.97it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.63it/s]
#                    all      0.841      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       46/70      5.52G     0.2835          6        224: 100%|██████████| 2429/2429 [03:23<00:00, 11.96it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.70it/s]
#                    all      0.842      0.985
#
#       Epoch    GPU_mem       loss  Instances       Size
#       47/70      5.52G      0.273          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.01it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:15<00:00, 20.30it/s]
#                    all      0.841      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       48/70      5.56G     0.2621          6        224: 100%|██████████| 2429/2429 [03:23<00:00, 11.94it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:15<00:00, 20.23it/s]
#                    all      0.842      0.986
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/70      5.52G      0.252          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 11.99it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.60it/s]
#                    all      0.841      0.985
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/70      5.58G     0.2384          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 11.99it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.39it/s]
#                    all      0.841      0.985
#
#       Epoch    GPU_mem       loss  Instances       Size
#       51/70      5.52G     0.2244          6        224: 100%|██████████| 2429/2429 [03:23<00:00, 11.96it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.46it/s]
#                    all      0.842      0.985
#
#       Epoch    GPU_mem       loss  Instances       Size
#       52/70      5.56G     0.2138          6        224: 100%|██████████| 2429/2429 [03:23<00:00, 11.96it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.55it/s]
#                    all      0.841      0.985
#
#       Epoch    GPU_mem       loss  Instances       Size
#       53/70      5.57G     0.2018          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.00it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.80it/s]
#                    all      0.842      0.985
#
#       Epoch    GPU_mem       loss  Instances       Size
#       54/70      5.52G     0.1893          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.00it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.65it/s]
#                    all      0.842      0.985
#
#       Epoch    GPU_mem       loss  Instances       Size
#       55/70      5.52G     0.1768          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.69it/s]
#                    all      0.843      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#       56/70      5.56G     0.1667          6        224: 100%|██████████| 2429/2429 [03:23<00:00, 11.96it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.52it/s]
#                    all      0.843      0.985
#
#       Epoch    GPU_mem       loss  Instances       Size
#       57/70      5.52G     0.1522          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.87it/s]
#                    all      0.843      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#       58/70      5.58G     0.1382          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.08it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:15<00:00, 20.09it/s]
#                    all      0.843      0.985
#
#       Epoch    GPU_mem       loss  Instances       Size
#       59/70      5.52G     0.1277          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.87it/s]
#                    all      0.843      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#       60/70      5.56G     0.1152          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.56it/s]
#                    all      0.843      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#       61/70      5.58G     0.1042          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.50it/s]
#                    all      0.843      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#       62/70      5.52G    0.09306          6        224: 100%|██████████| 2429/2429 [03:20<00:00, 12.09it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.53it/s]
#                    all      0.843      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#       63/70      5.52G    0.08152          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.08it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:15<00:00, 20.21it/s]
#                    all      0.843      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#       64/70      5.56G    0.06812          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.77it/s]
#                    all      0.842      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#       65/70      5.53G    0.05889          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.07it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.36it/s]
#                    all      0.842      0.983
#
#       Epoch    GPU_mem       loss  Instances       Size
#       66/70      5.58G     0.0482          6        224: 100%|██████████| 2429/2429 [03:22<00:00, 12.01it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.82it/s]
#                    all      0.842      0.983
#
#       Epoch    GPU_mem       loss  Instances       Size
#       67/70      5.52G     0.0436          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.06it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.73it/s]
#                    all      0.841      0.983
#
#       Epoch    GPU_mem       loss  Instances       Size
#       68/70      5.56G    0.03669          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.85it/s]
#                    all      0.841      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#       69/70      5.58G    0.02941          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.04it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:14<00:00, 20.50it/s]
#                    all      0.842      0.984
#
#       Epoch    GPU_mem       loss  Instances       Size
#       70/70      5.52G    0.02566          6        224: 100%|██████████| 2429/2429 [03:21<00:00, 12.05it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 305/305 [00:15<00:00, 19.60it/s]
#                    all      0.841      0.984
#
# 70 epochs completed in 4.247 hours.
# Optimizer stripped from /content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch_superClass/classify/weights/last.pt, 112.5MB
# Optimizer stripped from /content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch_superClass/classify/weights/best.pt, 112.5MB
# Results saved to /content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch_superClass/classify

# %% [markdown]
# ###Val

# %%
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.top1   # top1 accuracy
metrics.top5   # top5 accuracy
# Out:
# Ultralytics YOLOv8.0.119 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLOv8x-cls summary (fused): 133 layers, 56133448 parameters, 0 gradients
#                classes   top1_acc   top5_acc: 100%|██████████| 609/609 [00:22<00:00, 26.86it/s]
#                    all      0.831      0.987
# Speed: 0.1ms preprocess, 0.5ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/drive/MyDrive/Colab Notebooks/save_models/yolo_100epoch_superClass/classify2
# 0.9867491722106934
